# %%
import pandas as pd
import scipy as sp
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# %%
df = pd.read_csv('../artifacts/01_Data/Raw_data/10_ADCOR AR15.csv',header=None)
df.rename(columns={0:'acl_x',1:'acl_y',2:'acl_z'},inplace=True)
df
# Out:
#          acl_x    acl_y    acl_z
# 0      0.96875  0.18750 -0.43750
# 1      1.00000  0.18750 -0.46875
# 2      0.93750  0.15625 -0.50000
# 3      0.96875  0.21875 -0.43750
# 4      0.96875  0.21875 -0.46875
# ...        ...      ...      ...
# 32369  1.00000  0.25000 -0.09375
# 32370  1.00000  0.28125 -0.06250
# 32371  0.96875  0.28125 -0.06250
# 32372  0.96875  0.28125 -0.09375
# 32373  1.00000  0.28125 -0.06250
#
# [32374 rows x 3 columns]

# %%
sb.lineplot(df['acl_y'])#[10400:11200])

# for col in df.columns:
#     sb.lineplot(df[col])
# Out:
# <Axes: ylabel='acl_y'>

# %%
df2 = pd.read_csv('../artifacts/01_Data/Firearms_combined_data.csv',compression='gzip')
df2
# Out:
#           acl_x    acl_y    acl_z weapon_name  weapon_load weapon_type
# 0       0.56250  0.09375 -0.21875         M44            0       Rifle
# 1       0.56250  0.09375 -0.21875         M44            0       Rifle
# 2       0.56250  0.09375 -0.25000         M44            0       Rifle
# 3       0.56250  0.12500 -0.25000         M44            0       Rifle
# 4       0.53125  0.12500 -0.25000         M44            0       Rifle
# ...         ...      ...      ...         ...          ...         ...
# 539245  0.71875  0.28125 -0.53125    M16 AR15            1       Rifle
# 539246  0.71875  0.28125 -0.53125    M16 AR15            1       Rifle
# 539247  0.75000  0.25000 -0.53125    M16 AR15            1       Rifle
# 539248  0.71875  0.28125 -0.50000    M16 AR15            1       Rifle
# 539249  0.68750  0.28125 -0.53125    M16 AR15            1       Rifle
#
# [539250 rows x 6 columns]

# %%
df3 = pd.read_pickle('../artifacts/01_Data/Firearms_combined_data.pkl',compression='gzip')
df3
# Out:
#           acl_x    acl_y    acl_z weapon_name  weapon_load weapon_type
# 0       0.56250  0.09375 -0.21875         M44            0       Rifle
# 1       0.56250  0.09375 -0.21875         M44            0       Rifle
# 2       0.56250  0.09375 -0.25000         M44            0       Rifle
# 3       0.56250  0.12500 -0.25000         M44            0       Rifle
# 4       0.53125  0.12500 -0.25000         M44            0       Rifle
# ...         ...      ...      ...         ...          ...         ...
# 539245  0.71875  0.28125 -0.53125    M16 AR15            1       Rifle
# 539246  0.71875  0.28125 -0.53125    M16 AR15            1       Rifle
# 539247  0.75000  0.25000 -0.53125    M16 AR15            1       Rifle
# 539248  0.71875  0.28125 -0.50000    M16 AR15            1       Rifle
# 539249  0.68750  0.28125 -0.53125    M16 AR15            1       Rifle
#
# [539250 rows x 6 columns]
